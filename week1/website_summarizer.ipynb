# %%
import os
from dotenv import load_dotenv
from scraper import fetch_website_contents
from IPython.display import Markdown, display
from openai import OpenAI

# %%
load_dotenv(override=True)
api_key = os.getenv('OPENAI_API_KEY')

if not api_key:
    print("No API key was found - please head over to the troubleshooting notebook in this folder to identify & fix!")
elif not api_key.startswith("sk-proj-"):
    print("An API key was found, but it doesn't start sk-proj-; please check you're using the right key - see troubleshooting notebook")
elif api_key.strip() != api_key:
    print("An API key was found, but it looks like it might have space or tab characters at the start or end - please remove them - see troubleshooting notebook")
else:
    print("API key found and looks good so far!")
# Out:
# API key found and looks good so far!

# %%
message = "Hellow, GTP! This is my first ever message to you! Hi!"
messages = [
    { "role": "user", "content": message }
]

# %%
openai = OpenAI()

response = openai.chat.completions.create(model="gpt-5-nano", messages=messages)
response.choices[0].message.content
# Out:
# 'Hi there! Welcome, and nice to meet you. I’m here to help with almost anything—explain things, write or edit stuff, brainstorm ideas, plan things, learn, or just chat.\n\nWhat would you like to do today? If you’re not sure, here are some ideas:\n- Explain a concept in simple terms\n- Draft or edit an email, essay, resume, or post\n- Help with math, coding, or problem solving\n- Practice a language or have a friendly chat\n- Plan a trip, recipe, or workout\n\nTell me your goal, and we’ll dive in. What should we start with?'

# %%
santosh = fetch_website_contents("https://santoshdev.win/")
print(santosh)
# Out:
# Santosh Kumar - Software Development Engineer
#
# SK
# .
# Home
# About
# Projects
# Skills
# Experience
# Contact
# Hi there, I'm
# Santosh Kumar
# Software Development Engineer
# Building scalable and efficient full-stack applications with 1.4 years of experience. Passionate about solving real-world problems and writing clean code.
# Get In Touch
# View Projects
# Download Resume
# About Me
# A passionate Software Development Engineer with 1.4 years of experience in building scalable and efficient full-stack applications. I have a proven track record across several software projects in back-end, front-end, and cloud technologies.
# Software Development Engineer
# Currently at Sthambh, building robust products in microservices and event-driven architectures
# 1700+ LeetCode Problems
# Active competitive programmer with strong problem-solving skills
# Continuous Learner
# Currently learning System Design, Cloud Native technologies, and AI Agents
# Open Source Contributor
# ...

# %%
# Define system prompt
system_prompt = """
You are a snarky assistent that analyzes the contents of a website,
and provides a short, snarky, humorous summary, ignoring text that might be navigation related.
Response in markdown. Do not wrap the markdown in a code block - respond just with the markdown.
"""

# %%
# Define our user prompt
user_prompt_prefix = """
Here are the contents of a website.
Provide a short summary of this website.
If it includes news or announcements, then summarize these too.
"""

# %%
def messages_for(website):
    return [
        { "role": "system", "content": system_prompt },
        { "role": "user", "content": user_prompt_prefix + website }
    ]

# %%
messages_for(santosh)
# Out:
# [{'role': 'system',
#   'content': '\nYou are a snarky assistent that analyzes the contents of a website,\nand provides a short, snarky, humorous summary, ignoring text that might be navigation related.\nResponse in markdown. Do not wrap the markdown in a code block - respond just with the markdown.\n'},
#  {'role': 'user',
# ...

# %%
# Call the OpenAI API. You will get very familiar with this

def summarize(url):
    website = fetch_website_contents(url)
    response = openai.chat.completions.create(
        model = "gpt-4o-mini",
        messages = messages_for(website)
    )
    return response.choices[0].message.content

# %%
summarize("https://github.com/kumarsantosh3914")
# Out:
# 'Welcome to GitHub, where coders unite and bicker over semicolons! This site doesn’t just stop at storing code; it has a whole buffet of features like AI-driven code creation and workflow automation. It’s like the Swiss Army knife of software development tools. \n\nIn the news department, there’s a shiny new MCP Registry for integrating external tools because who doesn’t want more things to juggle? Also, they\'ve rolled out features for advanced application security, making it clear they take code security seriously – no one wants their precious code to be breached like a teenager’s diary! \n\nSo, whether you\'re a seasoned pro or just a curious amateur who likes to click "Fork," GitHub\'s got your back... as long as you can deal with the endless notifications of what your colleagues are up to. Happy coding!'

# %%
# A function to display this nicely in the output, using markdown

def display_summary(url):
    summary = summarize(url)
    display(Markdown(summary))

# %%
display_summary("https://github.com/kumarsantosh3914")
# Out:
# **GitHub: The Code Playground for Adults Who Still Can't Get Enough of Syntax Errors**
#
# Welcome to GitHub, where coding dreams go to mingle and occasionally crash! Here, you can write better code with AI—because who needs human programmers, right? With features like GitHub Copilot and Advanced Security, they promise to help you build applications while protecting you from disastrous leaks—both in your code and possibly in your life choices.
#
# They have it all: from actions that automate your chores to spaces as instant as your morning coffee. Whether you're a scrappy startup or a bloated enterprise, GitHub has a solution tailored for you—provided you can wade through the ocean of options.
#
# So grab your favorite caffeinated beverage and dive into this eclectic mix of developer tools, because in the world of coding, it's either collaborate or perish!

# %%
display_summary("https://anthropic.com")
# Out:
# Welcome to Anthropic, where they’re all about AI research that tries to be safer than your average horror movie. They specialize in making AI tools like Claude, a fancy assistant that claims it's here to help rather than haunt your dreams.
#
# ### Announcements:
# - **Claude Opus 4.7**: Launched on April 16, 2026, this updated model is here to be even smarter and tackle everything from coding to professional tasks. They basically threw an upgrade party for smartness.
# - **Claude is a space to think**: Announced on February 4, 2026, this initiative promises a no-ad experience—finally, a place where your thoughts won’t be interrupted by the latest cat meme!
#
# So, if you need an AI friend that won’t crash your brain—or your social life—Anthropic might just be your best bet.
